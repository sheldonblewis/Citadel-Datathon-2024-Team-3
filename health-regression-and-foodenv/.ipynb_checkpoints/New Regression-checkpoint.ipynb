# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# Assuming 'cleaned_data' is your DataFrame with predictor variables and no missing data

# Add polynomial features (degree 2) to the predictor variables
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(cleaned_data[predictor_columns])

# Create a DataFrame with the polynomial feature names
poly_feature_names = poly.get_feature_names_out(predictor_columns)
X_poly_df = pd.DataFrame(X_poly, columns=poly_feature_names)

# Add a constant term for the intercept in the regression
X_poly_df = sm.add_constant(X_poly_df)

# Calculate VIF for each predictor variable
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df.values, i) for i in range(X_poly_df.shape[1])]

# Sort the VIF data for better visualization
vif_data = vif_data.sort_values(by="VIF", ascending=False)

# Visualize VIF values using a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x="VIF", y="feature", data=vif_data, palette="viridis")
plt.title("Variance Inflation Factor (VIF) for Each Predictor")
plt.xlabel("VIF Value (log scale)")
plt.xscale("log")
plt.ylabel("Predictor Variables")
plt.show()
# Out:
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /var/folders/cv/0rgfl8cs40g0lnwkzp8sskhh0000gn/T/ipykernel_59619/314266829.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="VIF", y="feature", data=vif_data, palette="viridis")

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# Assuming 'cleaned_data' is your DataFrame with predictor variables and no missing data

# Add polynomial features (degree 2) to the predictor variables
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(cleaned_data[predictor_columns])

# Create a DataFrame with the polynomial feature names
poly_feature_names = poly.get_feature_names_out(predictor_columns)
X_poly_df = pd.DataFrame(X_poly, columns=poly_feature_names)

# Add a constant term for the intercept
X_poly_df = sm.add_constant(X_poly_df)

# Calculate VIF for each predictor variable
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df.values, i) for i in range(X_poly_df.shape[1])]

# Filter out features with VIF greater than 10 (commonly considered as high)
high_vif = vif_data[vif_data["VIF"] > 1]

# Print the high VIF values
print("Features with High VIF values (VIF > 10):")
print(high_vif)
# Out:
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Features with High VIF values (VIF > 10):
#                                             feature           VIF
# 1    Percent_change_fast_food_restaurants_2011_2016  6.196855e+04
# 2       Percent_change_convenience_stores_2011_2016  1.751196e+04
# 3                      Metro_nonmetro_counties_2010  1.286743e+15
# 4                             African American_2011  3.300959e+04
# 5                                        Asian_2011  2.775339e+05
# ..                                              ...           ...
# 148                           Obese_2011 Rural_2011  2.814294e+04
# 149                         Obese_2011 change_rural  3.400688e+02
# 150                                    Rural_2011^2  2.573054e+04
# 151                         Rural_2011 change_rural  8.707231e+03
# 152                                  change_rural^2  2.251875e+01
#
# [152 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = cleaned_data[predictor_columns].corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Predictor Variables")
plt.show()

# Optionally, print the most highly correlated pairs
high_corr_pairs = corr_matrix.abs().stack().reset_index().sort_values(0, ascending=False)
high_corr_pairs = high_corr_pairs[high_corr_pairs['level_0'] != high_corr_pairs['level_1']]
high_corr_pairs = high_corr_pairs[high_corr_pairs[0] > 0.9]  # Pairs with correlation greater than 0.9
print("Highly correlated pairs (correlation > 0.9):")
print(high_corr_pairs)
# Out:
# Highly correlated pairs (correlation > 0.9):
# Empty DataFrame
# Columns: [level_0, level_1, 0]
# Index: []

# %%
cleaned_data = merged_data

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3137 entries, 0 to 3136
# Data columns (total 38 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   FIPS                                                  3137 non-null   int64
#  1   State_2011                                            3137 non-null   object
#  2   County_2011                                           3137 non-null   object
#  3   Rural_2011                                            3136 non-null   float64
#  4   Household Income_2011                                 3136 non-null   float64
#  5   African American_2011                                 3137 non-null   float64
#  6   Asian_2011                                            3137 non-null   float64
#  7   Hispanic_2011                                         3137 non-null   float64
#  8   Obese_2011                                            3137 non-null   float64
#  9   PCP Ratio_2011                                        3137 non-null   object
#  10  change_rural                                          3136 non-null   float64
#  11  change_obese                                          3137 non-null   float64
#  12  change_binge_drinking                                 2604 non-null   float64
#  13  change_physical_inactivity                            3137 non-null   float64
#  14  change_mentally_unhealthy_days                        2941 non-null   float64
#  15  change_fair_poor_health                               2736 non-null   float64
#  16  Percent_change_fast_food_restaurants_2011_2016        3085 non-null   float64
#  17  Percent_change_convenience_stores_2011_2016           3116 non-null   float64
#  18  Metro_nonmetro_counties_2010                          3137 non-null   int64
#  19  Persistent_poverty_counties_2010                      3137 non-null   int64
#  20  Population_loss_counties_2010                         3135 non-null   float64
#  21  Recreation_fitness_facilities_2011                    3137 non-null   float64
#  22  Grocery_stores_2011                                   3137 non-null   float64
#  23  Low_access_to_stores_2010                             3137 non-null   float64
#  24  SNAP_benefits_per_capita_2012                         3081 non-null   float64
#  25  WIC_redemptions_per_capita_2011                       2032 non-null   float64
#  26  Rural_2011_fast_food_interaction                      3084 non-null   float64
#  27  Rural_2011_convenience_stores_interaction             3115 non-null   float64
#  28  Household Income_2011_fast_food_interaction           3084 non-null   float64
#  29  Household Income_2011_convenience_stores_interaction  3115 non-null   float64
#  30  Obese_2011_fast_food_interaction                      3085 non-null   float64
#  31  Obese_2011_convenience_stores_interaction             3116 non-null   float64
#  32  African American_2011_fast_food_interaction           3085 non-null   float64
#  33  African American_2011_convenience_stores_interaction  3116 non-null   float64
#  34  Asian_2011_fast_food_interaction                      3085 non-null   float64
#  35  Asian_2011_convenience_stores_interaction             3116 non-null   float64
#  36  Hispanic_2011_fast_food_interaction                   3085 non-null   float64
#  37  Hispanic_2011_convenience_stores_interaction          3116 non-null   float64
# dtypes: float64(32), int64(3), object(3)
# memory usage: 931.4+ KB

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np

# Assuming predictor_columns and response_columns are already defined

# Create interaction terms manually or use PolynomialFeatures
interaction_columns = [
    'Rural_2011', 'Household Income_2011', 'Obese_2011', 
    'African American_2011', 'Asian_2011', 'Hispanic_2011'
]

# Generate interaction terms
interaction_terms = [
    'Rural_2011_fast_food_interaction',
    'Household Income_2011_fast_food_interaction',
    'Obese_2011_fast_food_interaction',
    'African American_2011_fast_food_interaction',
    'Asian_2011_fast_food_interaction',
    'Hispanic_2011_fast_food_interaction',
    'Rural_2011_convenience_stores_interaction',
    'Household Income_2011_convenience_stores_interaction',
    'Obese_2011_convenience_stores_interaction',
    'African American_2011_convenience_stores_interaction',
    'Asian_2011_convenience_stores_interaction',
    'Hispanic_2011_convenience_stores_interaction'
]

# Include the original predictors and the interaction terms
predictors_with_interactions = predictor_columns + interaction_terms

# Add a constant term
X_interaction = sm.add_constant(cleaned_data[predictors_with_interactions])

# Check for NaN or Inf values in the predictors
X_interaction = X_interaction.replace([np.inf, -np.inf], np.nan).dropna()

# Loop over each response variable and run the regression
for response in response_columns:
    # Align the indices of Y with X_interaction
    Y = cleaned_data.loc[X_interaction.index, response]
    
    # Fit the model
    model = sm.OLS(Y, X_interaction).fit()
    
    print(f'Results for {response}:')
    print(model.summary())
    print('\n\n')
# Out:
# Results for change_obese:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     12.68
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):           1.04e-54
# Time:                        23:50:13   Log-Likelihood:                -6849.9
# No. Observations:                3008   AIC:                         1.376e+04
# Df Residuals:                    2979   BIC:                         1.393e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                    7.5871      0.649     11.688      0.000       6.314       8.860
# Percent_change_fast_food_restaurants_2011_2016           0.0656      0.017      3.918      0.000       0.033       0.098
# Percent_change_convenience_stores_2011_2016              0.0165      0.022      0.738      0.461      -0.027       0.061
# Metro_nonmetro_counties_2010                            -0.1487      0.115     -1.298      0.194      -0.373       0.076
# African American_2011                                    0.0068      0.004      1.627      0.104      -0.001       0.015
# Asian_2011                                              -0.1019      0.023     -4.458      0.000      -0.147      -0.057
# Hispanic_2011                                           -0.0096      0.004     -2.475      0.013      -0.017      -0.002
# Persistent_poverty_counties_2010                        -0.2184      0.177     -1.237      0.216      -0.564       0.128
# Population_loss_counties_2010                            0.4697      0.129      3.651      0.000       0.217       0.722
# Recreation_fitness_facilities_2011                      -2.4803      0.693     -3.580      0.000      -3.839      -1.122
# Grocery_stores_2011                                     -1.2084      0.231     -5.225      0.000      -1.662      -0.755
# Low_access_to_stores_2010                             -2.67e-06   1.04e-06     -2.556      0.011   -4.72e-06   -6.21e-07
# SNAP_benefits_per_capita_2012                            0.0112      0.006      1.764      0.078      -0.001       0.024
# Household Income_2011                                -2.979e-05   6.64e-06     -4.485      0.000   -4.28e-05   -1.68e-05
# Obese_2011                                              -0.1397      0.016     -8.615      0.000      -0.172      -0.108
# Rural_2011                                               0.0043      0.002      2.026      0.043       0.000       0.008
# change_rural                                             0.0188      0.007      2.563      0.010       0.004       0.033
# Rural_2011_fast_food_interaction                        -0.0001   5.89e-05     -2.062      0.039      -0.000   -5.99e-06
# Household Income_2011_fast_food_interaction          -4.175e-07   1.65e-07     -2.530      0.011   -7.41e-07    -9.4e-08
# Obese_2011_fast_food_interaction                        -0.0012      0.000     -2.816      0.005      -0.002      -0.000
# African American_2011_fast_food_interaction          -4.661e-05   9.74e-05     -0.479      0.632      -0.000       0.000
# Asian_2011_fast_food_interaction                        -0.0021      0.001     -2.009      0.045      -0.004   -5.18e-05
# Hispanic_2011_fast_food_interaction                     -0.0002      0.000     -1.576      0.115      -0.000    4.37e-05
# Rural_2011_convenience_stores_interaction               -0.0001   6.82e-05     -1.690      0.091      -0.000    1.85e-05
# Household Income_2011_convenience_stores_interaction -1.681e-07   1.93e-07     -0.870      0.384   -5.47e-07    2.11e-07
# Obese_2011_convenience_stores_interaction                0.0001      0.001      0.237      0.812      -0.001       0.001
# African American_2011_convenience_stores_interaction  -9.14e-06      0.000     -0.078      0.938      -0.000       0.000
# Asian_2011_convenience_stores_interaction            -2.863e-05      0.002     -0.017      0.986      -0.003       0.003
# Hispanic_2011_convenience_stores_interaction            -0.0002      0.000     -1.869      0.062      -0.000    1.15e-05
# ==============================================================================
# Omnibus:                       35.145   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.549
# Skew:                           0.097   Prob(JB):                     1.43e-12
# Kurtosis:                       3.631   Cond. No.                     2.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for change_physical_inactivity:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     change_physical_inactivity   R-squared:                       0.044
# Model:                                    OLS   Adj. R-squared:                  0.035
# Method:                         Least Squares   F-statistic:                     4.873
# Date:                        Sat, 03 Aug 2024   Prob (F-statistic):           8.75e-16
# Time:                                23:50:13   Log-Likelihood:                -7454.9
# No. Observations:                        3008   AIC:                         1.497e+04
# Df Residuals:                            2979   BIC:                         1.514e+04
# Df Model:                                  28
# Covariance Type:                    nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                    1.6465      0.794      2.074      0.038       0.090       3.203
# Percent_change_fast_food_restaurants_2011_2016           0.0384      0.020      1.879      0.060      -0.002       0.079
# Percent_change_convenience_stores_2011_2016              0.0339      0.027      1.236      0.217      -0.020       0.088
# Metro_nonmetro_counties_2010                             0.1172      0.140      0.836      0.403      -0.158       0.392
# African American_2011                                    0.0025      0.005      0.500      0.617      -0.007       0.013
# Asian_2011                                              -0.0250      0.028     -0.895      0.371      -0.080       0.030
# Hispanic_2011                                            0.0025      0.005      0.537      0.592      -0.007       0.012
# Persistent_poverty_counties_2010                        -0.5811      0.216     -2.693      0.007      -1.004      -0.158
# Population_loss_counties_2010                            0.1299      0.157      0.826      0.409      -0.179       0.438
# Recreation_fitness_facilities_2011                      -0.9969      0.847     -1.177      0.239      -2.658       0.664
# Grocery_stores_2011                                     -0.5394      0.283     -1.908      0.057      -1.094       0.015
# Low_access_to_stores_2010                            -1.469e-06   1.28e-06     -1.150      0.250   -3.97e-06    1.04e-06
# SNAP_benefits_per_capita_2012                           -0.0170      0.008     -2.196      0.028      -0.032      -0.002
# Household Income_2011                                -1.558e-05   8.12e-06     -1.919      0.055   -3.15e-05    3.41e-07
# Obese_2011                                              -0.0281      0.020     -1.415      0.157      -0.067       0.011
# Rural_2011                                               0.0125      0.003      4.853      0.000       0.007       0.018
# change_rural                                             0.0101      0.009      1.123      0.261      -0.008       0.028
# Rural_2011_fast_food_interaction                      -1.81e-05    7.2e-05     -0.252      0.801      -0.000       0.000
# Household Income_2011_fast_food_interaction          -8.287e-08   2.02e-07     -0.411      0.681   -4.79e-07    3.13e-07
# Obese_2011_fast_food_interaction                        -0.0013      0.001     -2.606      0.009      -0.002      -0.000
# African American_2011_fast_food_interaction              0.0004      0.000      3.103      0.002       0.000       0.001
# Asian_2011_fast_food_interaction                        -0.0012      0.001     -0.934      0.350      -0.004       0.001
# Hispanic_2011_fast_food_interaction                  -2.738e-06      0.000     -0.020      0.984      -0.000       0.000
# Rural_2011_convenience_stores_interaction               -0.0001   8.34e-05     -1.297      0.195      -0.000    5.53e-05
# Household Income_2011_convenience_stores_interaction -3.997e-07   2.36e-07     -1.692      0.091   -8.63e-07    6.34e-08
# Obese_2011_convenience_stores_interaction               -0.0001      0.001     -0.183      0.855      -0.001       0.001
# African American_2011_convenience_stores_interaction -8.738e-05      0.000     -0.612      0.540      -0.000       0.000
# Asian_2011_convenience_stores_interaction                0.0022      0.002      1.075      0.282      -0.002       0.006
# Hispanic_2011_convenience_stores_interaction            -0.0001      0.000     -0.771      0.441      -0.000       0.000
# ==============================================================================
# Omnibus:                       44.023   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.009
# Skew:                           0.108   Prob(JB):                     1.40e-16
# Kurtosis:                       3.732   Cond. No.                     2.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for change_mentally_unhealthy_days:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     change_mentally_unhealthy_days   R-squared:                         nan
# Model:                                        OLS   Adj. R-squared:                    nan
# Method:                             Least Squares   F-statistic:                       nan
# Date:                            Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                                    23:50:13   Log-Likelihood:                    nan
# No. Observations:                            3008   AIC:                               nan
# Df Residuals:                                2979   BIC:                               nan
# Df Model:                                      28
# Covariance Type:                        nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                       nan        nan        nan        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016              nan        nan        nan        nan         nan         nan
# Percent_change_convenience_stores_2011_2016                 nan        nan        nan        nan         nan         nan
# Metro_nonmetro_counties_2010                                nan        nan        nan        nan         nan         nan
# African American_2011                                       nan        nan        nan        nan         nan         nan
# Asian_2011                                                  nan        nan        nan        nan         nan         nan
# Hispanic_2011                                               nan        nan        nan        nan         nan         nan
# Persistent_poverty_counties_2010                            nan        nan        nan        nan         nan         nan
# Population_loss_counties_2010                               nan        nan        nan        nan         nan         nan
# Recreation_fitness_facilities_2011                          nan        nan        nan        nan         nan         nan
# Grocery_stores_2011                                         nan        nan        nan        nan         nan         nan
# Low_access_to_stores_2010                                   nan        nan        nan        nan         nan         nan
# SNAP_benefits_per_capita_2012                               nan        nan        nan        nan         nan         nan
# Household Income_2011                                       nan        nan        nan        nan         nan         nan
# Obese_2011                                                  nan        nan        nan        nan         nan         nan
# Rural_2011                                                  nan        nan        nan        nan         nan         nan
# change_rural                                                nan        nan        nan        nan         nan         nan
# Rural_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# Household Income_2011_fast_food_interaction                 nan        nan        nan        nan         nan         nan
# Obese_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# African American_2011_fast_food_interaction                 nan        nan        nan        nan         nan         nan
# Asian_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# Hispanic_2011_fast_food_interaction                         nan        nan        nan        nan         nan         nan
# Rural_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# Household Income_2011_convenience_stores_interaction        nan        nan        nan        nan         nan         nan
# Obese_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# African American_2011_convenience_stores_interaction        nan        nan        nan        nan         nan         nan
# Asian_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction                nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     2.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for change_fair_poor_health:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     change_fair_poor_health   R-squared:                         nan
# Model:                                 OLS   Adj. R-squared:                    nan
# Method:                      Least Squares   F-statistic:                       nan
# Date:                     Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                             23:50:13   Log-Likelihood:                    nan
# No. Observations:                     3008   AIC:                               nan
# Df Residuals:                         2979   BIC:                               nan
# Df Model:                               28
# Covariance Type:                 nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                       nan        nan        nan        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016              nan        nan        nan        nan         nan         nan
# Percent_change_convenience_stores_2011_2016                 nan        nan        nan        nan         nan         nan
# Metro_nonmetro_counties_2010                                nan        nan        nan        nan         nan         nan
# African American_2011                                       nan        nan        nan        nan         nan         nan
# Asian_2011                                                  nan        nan        nan        nan         nan         nan
# Hispanic_2011                                               nan        nan        nan        nan         nan         nan
# Persistent_poverty_counties_2010                            nan        nan        nan        nan         nan         nan
# Population_loss_counties_2010                               nan        nan        nan        nan         nan         nan
# Recreation_fitness_facilities_2011                          nan        nan        nan        nan         nan         nan
# Grocery_stores_2011                                         nan        nan        nan        nan         nan         nan
# Low_access_to_stores_2010                                   nan        nan        nan        nan         nan         nan
# SNAP_benefits_per_capita_2012                               nan        nan        nan        nan         nan         nan
# Household Income_2011                                       nan        nan        nan        nan         nan         nan
# Obese_2011                                                  nan        nan        nan        nan         nan         nan
# Rural_2011                                                  nan        nan        nan        nan         nan         nan
# change_rural                                                nan        nan        nan        nan         nan         nan
# Rural_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# Household Income_2011_fast_food_interaction                 nan        nan        nan        nan         nan         nan
# Obese_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# African American_2011_fast_food_interaction                 nan        nan        nan        nan         nan         nan
# Asian_2011_fast_food_interaction                            nan        nan        nan        nan         nan         nan
# Hispanic_2011_fast_food_interaction                         nan        nan        nan        nan         nan         nan
# Rural_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# Household Income_2011_convenience_stores_interaction        nan        nan        nan        nan         nan         nan
# Obese_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# African American_2011_convenience_stores_interaction        nan        nan        nan        nan         nan         nan
# Asian_2011_convenience_stores_interaction                   nan        nan        nan        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction                nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     2.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.api as sm
import pandas as pd

# Initialize a dictionary to store the results for each state
statewise_results = {}

# Get the list of unique states
states = cleaned_data['State_2011'].unique()

# Loop over each state
for state in states:
    # Filter the data for the current state
    state_data = cleaned_data[cleaned_data['State_2011'] == state]
    
    # Drop rows with NaNs or Infs
    X_state = sm.add_constant(state_data[predictors_with_interactions].replace([np.inf, -np.inf], np.nan).dropna())
    Y_state = state_data.loc[X_state.index, 'change_obese']  # Align Y with X
    
    # Ensure there are enough data points to run the model
    if len(Y_state) < 2:
        print(f"Not enough data points for {state}. Skipping this state.")
        continue
    
    # Fit the model
    model_state = sm.OLS(Y_state, X_state).fit()
    
    # Store the summary in the dictionary
    statewise_results[state] = model_state.summary()

# Print results for each state
for state, summary in statewise_results.items():
    print(f"Results for {state}:")
    print(summary)
    print('\n\n')
# Out:
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/base/model.py:1527: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=15 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=16 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/base/model.py:1527: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/base/model.py:1527: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1796: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1718: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /Users/adelmuursepp/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/statsmodels/base/model.py:1527: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# Results for Wisconsin:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     1.133
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):              0.349
# Time:                        23:56:08   Log-Likelihood:                -142.23
# No. Observations:                  71   AIC:                             338.5
# Df Residuals:                      44   BIC:                             399.5
# Df Model:                          26
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   25.9259     11.413      2.272      0.028       2.924      48.927
# Percent_change_fast_food_restaurants_2011_2016          -0.1460      0.374     -0.391      0.698      -0.899       0.607
# Percent_change_convenience_stores_2011_2016             -0.0181      0.615     -0.030      0.977      -1.258       1.221
# Metro_nonmetro_counties_2010                             0.8160      1.058      0.771      0.445      -1.317       2.949
# African American_2011                                    0.0216      0.212      0.102      0.919      -0.405       0.448
# Asian_2011                                              -1.0753      0.524     -2.053      0.046      -2.131      -0.019
# Hispanic_2011                                           -0.0003      0.228     -0.001      0.999      -0.460       0.460
# Persistent_poverty_counties_2010                      1.819e-12   2.11e-12      0.861      0.394   -2.44e-12    6.07e-12
# Population_loss_counties_2010                        -3.334e-13   2.79e-13     -1.197      0.238   -8.95e-13    2.28e-13
# Recreation_fitness_facilities_2011                      -8.2496      6.905     -1.195      0.239     -22.166       5.666
# Grocery_stores_2011                                     -6.8087      4.552     -1.496      0.142     -15.982       2.365
# Low_access_to_stores_2010                            -3.405e-06   1.85e-05     -0.184      0.855   -4.07e-05    3.39e-05
# SNAP_benefits_per_capita_2012                           -0.0525      0.131     -0.401      0.691      -0.316       0.211
# Household Income_2011                                -6.968e-05   9.93e-05     -0.701      0.487      -0.000       0.000
# Obese_2011                                              -0.6257      0.325     -1.925      0.061      -1.281       0.030
# Rural_2011                                               0.0079      0.024      0.330      0.743      -0.040       0.056
# change_rural                                             0.0067      0.111      0.060      0.952      -0.217       0.230
# Rural_2011_fast_food_interaction                         0.0007      0.001      0.581      0.564      -0.002       0.003
# Household Income_2011_fast_food_interaction           1.757e-06   3.19e-06      0.552      0.584   -4.66e-06    8.18e-06
# Obese_2011_fast_food_interaction                        -0.0007      0.016     -0.046      0.964      -0.033       0.031
# African American_2011_fast_food_interaction              0.0169      0.019      0.895      0.376      -0.021       0.055
# Asian_2011_fast_food_interaction                         0.0531      0.044      1.205      0.235      -0.036       0.142
# Hispanic_2011_fast_food_interaction                     -0.0028      0.017     -0.161      0.873      -0.038       0.032
# Rural_2011_convenience_stores_interaction               -0.0014      0.001     -0.963      0.341      -0.004       0.002
# Household Income_2011_convenience_stores_interaction  -6.28e-06   3.38e-06     -1.858      0.070   -1.31e-05    5.31e-07
# Obese_2011_convenience_stores_interaction                0.0123      0.024      0.504      0.617      -0.037       0.062
# African American_2011_convenience_stores_interaction    -0.0464      0.033     -1.385      0.173      -0.114       0.021
# Asian_2011_convenience_stores_interaction                0.0470      0.034      1.384      0.173      -0.021       0.115
# Hispanic_2011_convenience_stores_interaction             0.0442      0.029      1.510      0.138      -0.015       0.103
# ==============================================================================
# Omnibus:                        5.321   Durbin-Watson:                   2.286
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                4.691
# Skew:                          -0.619   Prob(JB):                       0.0958
# Kurtosis:                       3.235   Cond. No.                     1.16e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.15e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# Results for Washington:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.037
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):              0.505
# Time:                        23:56:08   Log-Likelihood:                -59.898
# No. Observations:                  37   AIC:                             173.8
# Df Residuals:                      10   BIC:                             217.3
# Df Model:                          26
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -9.7688     13.072     -0.747      0.472     -38.896      19.358
# Percent_change_fast_food_restaurants_2011_2016           0.5964      0.866      0.689      0.507      -1.333       2.525
# Percent_change_convenience_stores_2011_2016             -1.0929      0.640     -1.709      0.118      -2.518       0.332
# Metro_nonmetro_counties_2010                            -0.0665      1.902     -0.035      0.973      -4.305       4.172
# African American_2011                                   -1.6070      1.772     -0.907      0.386      -5.555       2.341
# Asian_2011                                              -1.1241      0.959     -1.172      0.268      -3.260       1.012
# Hispanic_2011                                            0.0664      0.091      0.732      0.481      -0.136       0.268
# Persistent_poverty_counties_2010                     -3.769e-11    8.1e-11     -0.466      0.652   -2.18e-10    1.43e-10
# Population_loss_counties_2010                         2.174e-11    4.2e-11      0.518      0.616   -7.19e-11    1.15e-10
# Recreation_fitness_facilities_2011                      -4.0405     19.504     -0.207      0.840     -47.498      39.417
# Grocery_stores_2011                                     23.8186     12.003      1.984      0.075      -2.925      50.562
# Low_access_to_stores_2010                             1.661e-05   3.26e-05      0.510      0.621    -5.6e-05    8.92e-05
# SNAP_benefits_per_capita_2012                           -0.0559      0.247     -0.226      0.826      -0.607       0.495
# Household Income_2011                                    0.0004      0.000      1.496      0.166      -0.000       0.001
# Obese_2011                                              -0.3341      0.342     -0.977      0.352      -1.096       0.428
# Rural_2011                                              -0.0485      0.041     -1.171      0.269      -0.141       0.044
# change_rural                                            -0.0415      0.136     -0.305      0.767      -0.345       0.262
# Rural_2011_fast_food_interaction                        -0.0016      0.004     -0.384      0.709      -0.011       0.008
# Household Income_2011_fast_food_interaction            2.88e-05   2.54e-05      1.135      0.283   -2.77e-05    8.53e-05
# Obese_2011_fast_food_interaction                        -0.0573      0.028     -2.051      0.067      -0.120       0.005
# African American_2011_fast_food_interaction             -0.1461      0.314     -0.466      0.651      -0.845       0.553
# Asian_2011_fast_food_interaction                        -0.1382      0.158     -0.873      0.403      -0.491       0.214
# Hispanic_2011_fast_food_interaction                      0.0116      0.011      1.055      0.316      -0.013       0.036
# Rural_2011_convenience_stores_interaction               -0.0008      0.003     -0.302      0.769      -0.006       0.005
# Household Income_2011_convenience_stores_interaction  1.074e-05      1e-05      1.072      0.309   -1.16e-05     3.3e-05
# Obese_2011_convenience_stores_interaction                0.0213      0.010      2.226      0.050   -1.84e-05       0.043
# African American_2011_convenience_stores_interaction    -0.1775      0.127     -1.400      0.192      -0.460       0.105
# Asian_2011_convenience_stores_interaction                0.0921      0.064      1.450      0.178      -0.049       0.234
# Hispanic_2011_convenience_stores_interaction            -0.0016      0.004     -0.465      0.652      -0.010       0.006
# ==============================================================================
# Omnibus:                        4.688   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                3.271
# Skew:                           0.593   Prob(JB):                        0.195
# Kurtosis:                       3.845   Cond. No.                     1.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.56e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# Results for New Hampshire:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                        23:56:09   Log-Likelihood:                 253.59
# No. Observations:                  10   AIC:                            -487.2
# Df Residuals:                       0   BIC:                            -484.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.0005        inf         -0        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016           0.0281        inf          0        nan         nan         nan
# Percent_change_convenience_stores_2011_2016             -0.0260        inf         -0        nan         nan         nan
# Metro_nonmetro_counties_2010                            -0.0085        inf         -0        nan         nan         nan
# African American_2011                                    0.0107        inf          0        nan         nan         nan
# Asian_2011                                               0.0155        inf          0        nan         nan         nan
# Hispanic_2011                                            0.0123        inf          0        nan         nan         nan
# Persistent_poverty_counties_2010                      1.167e-16        inf          0        nan         nan         nan
# Population_loss_counties_2010                            0.0206        inf          0        nan         nan         nan
# Recreation_fitness_facilities_2011                   -8.231e-05        inf         -0        nan         nan         nan
# Grocery_stores_2011                                     -0.0026        inf         -0        nan         nan         nan
# Low_access_to_stores_2010                                0.0001        inf          0        nan         nan         nan
# SNAP_benefits_per_capita_2012                            0.0678        inf          0        nan         nan         nan
# Household Income_2011                                    0.0002        inf          0        nan         nan         nan
# Obese_2011                                              -0.0421        inf         -0        nan         nan         nan
# Rural_2011                                              -0.1464        inf         -0        nan         nan         nan
# change_rural                                             0.0330        inf          0        nan         nan         nan
# Rural_2011_fast_food_interaction                        -0.0644        inf         -0        nan         nan         nan
# Household Income_2011_fast_food_interaction           6.286e-05        inf          0        nan         nan         nan
# Obese_2011_fast_food_interaction                         0.0305        inf          0        nan         nan         nan
# African American_2011_fast_food_interaction             -0.1048        inf         -0        nan         nan         nan
# Asian_2011_fast_food_interaction                         0.1305        inf          0        nan         nan         nan
# Hispanic_2011_fast_food_interaction                     -0.0759        inf         -0        nan         nan         nan
# Rural_2011_convenience_stores_interaction                0.0341        inf          0        nan         nan         nan
# Household Income_2011_convenience_stores_interaction   4.17e-05        inf          0        nan         nan         nan
# Obese_2011_convenience_stores_interaction               -0.1633        inf         -0        nan         nan         nan
# African American_2011_convenience_stores_interaction     0.1370        inf          0        nan         nan         nan
# Asian_2011_convenience_stores_interaction                0.1009        inf          0        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction             0.1070        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.035   Durbin-Watson:                   2.549
# Prob(Omnibus):                  0.596   Jarque-Bera (JB):                0.357
# Skew:                          -0.451   Prob(JB):                        0.836
# Kurtosis:                       2.786   Cond. No.                     3.03e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for Alaska:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                        23:56:09   Log-Likelihood:                 444.40
# No. Observations:                  22   AIC:                            -844.8
# Df Residuals:                       0   BIC:                            -820.8
# Df Model:                          21
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                    0.0038        inf          0        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016           0.8604        inf          0        nan         nan         nan
# Percent_change_convenience_stores_2011_2016              0.5636        inf          0        nan         nan         nan
# Metro_nonmetro_counties_2010                            -0.1099        inf         -0        nan         nan         nan
# African American_2011                                   -0.2274        inf         -0        nan         nan         nan
# Asian_2011                                               0.4884        inf          0        nan         nan         nan
# Hispanic_2011                                           -0.9043        inf         -0        nan         nan         nan
# Persistent_poverty_counties_2010                        -0.1982        inf         -0        nan         nan         nan
# Population_loss_counties_2010                           -0.1908        inf         -0        nan         nan         nan
# Recreation_fitness_facilities_2011                      -0.0077        inf         -0        nan         nan         nan
# Grocery_stores_2011                                      0.7103        inf          0        nan         nan         nan
# Low_access_to_stores_2010                             6.254e-05        inf          0        nan         nan         nan
# SNAP_benefits_per_capita_2012                            0.1304        inf          0        nan         nan         nan
# Household Income_2011                                    0.0004        inf          0        nan         nan         nan
# Obese_2011                                              -1.0357        inf         -0        nan         nan         nan
# Rural_2011                                               0.0480        inf          0        nan         nan         nan
# change_rural                                             0.1374        inf          0        nan         nan         nan
# Rural_2011_fast_food_interaction                         0.0039        inf          0        nan         nan         nan
# Household Income_2011_fast_food_interaction          -1.073e-05        inf         -0        nan         nan         nan
# Obese_2011_fast_food_interaction                        -0.0158        inf         -0        nan         nan         nan
# African American_2011_fast_food_interaction             -0.1331        inf         -0        nan         nan         nan
# Asian_2011_fast_food_interaction                         0.0054        inf          0        nan         nan         nan
# Hispanic_2011_fast_food_interaction                      0.0258        inf          0        nan         nan         nan
# Rural_2011_convenience_stores_interaction                0.0045        inf          0        nan         nan         nan
# Household Income_2011_convenience_stores_interaction  7.457e-07        inf          0        nan         nan         nan
# Obese_2011_convenience_stores_interaction               -0.0368        inf         -0        nan         nan         nan
# African American_2011_convenience_stores_interaction    -0.0037        inf         -0        nan         nan         nan
# Asian_2011_convenience_stores_interaction               -0.0332        inf         -0        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction             0.0950        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.368   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.505   Jarque-Bera (JB):                0.284
# Skew:                           0.068   Prob(JB):                        0.868
# Kurtosis:                       3.540   Cond. No.                     1.25e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 1.25e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for Hawaii:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                        23:56:09   Log-Likelihood:                 101.67
# No. Observations:                   3   AIC:                            -197.3
# Df Residuals:                       0   BIC:                            -200.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 4.328e-11        inf          0        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016       -3.995e-11        inf         -0        nan         nan         nan
# Percent_change_convenience_stores_2011_2016          -2.156e-11        inf         -0        nan         nan         nan
# Metro_nonmetro_counties_2010                          2.225e-11        inf          0        nan         nan         nan
# African American_2011                                 1.103e-10        inf          0        nan         nan         nan
# Asian_2011                                             1.59e-09        inf          0        nan         nan         nan
# Hispanic_2011                                         4.096e-10        inf          0        nan         nan         nan
# Persistent_poverty_counties_2010                              0        nan        nan        nan         nan         nan
# Population_loss_counties_2010                                 0        nan        nan        nan         nan         nan
# Recreation_fitness_facilities_2011                    2.527e-12        inf          0        nan         nan         nan
# Grocery_stores_2011                                   1.002e-11        inf          0        nan         nan         nan
# Low_access_to_stores_2010                             5.086e-06        inf          0        nan         nan         nan
# SNAP_benefits_per_capita_2012                         1.295e-09        inf          0        nan         nan         nan
# Household Income_2011                                 2.794e-06        inf          0        nan         nan         nan
# Obese_2011                                             9.06e-10        inf          0        nan         nan         nan
# Rural_2011                                             5.95e-10        inf          0        nan         nan         nan
# change_rural                                         -1.276e-10        inf         -0        nan         nan         nan
# Rural_2011_fast_food_interaction                      -2.47e-09        inf         -0        nan         nan         nan
# Household Income_2011_fast_food_interaction          -1.668e-06        inf         -0        nan         nan         nan
# Obese_2011_fast_food_interaction                     -9.313e-10        inf         -0        nan         nan         nan
# African American_2011_fast_food_interaction          -1.259e-11        inf         -0        nan         nan         nan
# Asian_2011_fast_food_interaction                     -5.805e-10        inf         -0        nan         nan         nan
# Hispanic_2011_fast_food_interaction                  -5.407e-10        inf         -0        nan         nan         nan
# Rural_2011_convenience_stores_interaction            -2.986e-09        inf         -0        nan         nan         nan
# Household Income_2011_convenience_stores_interaction  1.219e-08        inf          0        nan         nan         nan
# Obese_2011_convenience_stores_interaction            -7.819e-10        inf         -0        nan         nan         nan
# African American_2011_convenience_stores_interaction -3.885e-10        inf         -0        nan         nan         nan
# Asian_2011_convenience_stores_interaction            -2.077e-10        inf         -0        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction         -2.911e-10        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.191
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.325
# Skew:                          -0.295   Prob(JB):                        0.850
# Kurtosis:                       1.500   Cond. No.                         8.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
#
#
#
# Results for South Dakota:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     1.158
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):              0.346
# Time:                        23:56:09   Log-Likelihood:                -102.39
# No. Observations:                  59   AIC:                             262.8
# Df Residuals:                      30   BIC:                             323.0
# Df Model:                          28
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   12.7348      7.146      1.782      0.085      -1.859      27.329
# Percent_change_fast_food_restaurants_2011_2016          -0.1670      0.168     -0.997      0.327      -0.509       0.175
# Percent_change_convenience_stores_2011_2016             -0.2209      0.260     -0.849      0.403      -0.752       0.311
# Metro_nonmetro_counties_2010                             0.1660      1.229      0.135      0.893      -2.344       2.676
# African American_2011                                    0.2373      1.012      0.234      0.816      -1.830       2.304
# Asian_2011                                               1.0647      0.815      1.307      0.201      -0.599       2.729
# Hispanic_2011                                           -0.5863      0.469     -1.249      0.221      -1.545       0.372
# Persistent_poverty_counties_2010                         0.8761      1.875      0.467      0.644      -2.953       4.705
# Population_loss_counties_2010                            0.6670      0.778      0.857      0.398      -0.922       2.256
# Recreation_fitness_facilities_2011                      -5.3009      3.059     -1.733      0.093     -11.547       0.946
# Grocery_stores_2011                                     -1.1022      1.400     -0.787      0.437      -3.962       1.758
# Low_access_to_stores_2010                            -5.905e-05   8.27e-05     -0.714      0.481      -0.000       0.000
# SNAP_benefits_per_capita_2012                            0.0386      0.067      0.573      0.571      -0.099       0.176
# Household Income_2011                                -1.973e-05   7.22e-05     -0.273      0.787      -0.000       0.000
# Obese_2011                                              -0.3561      0.228     -1.563      0.129      -0.821       0.109
# Rural_2011                                               0.0145      0.018      0.787      0.438      -0.023       0.052
# change_rural                                            -0.0506      0.052     -0.972      0.339      -0.157       0.056
# Rural_2011_fast_food_interaction                        -0.0004      0.000     -0.827      0.415      -0.001       0.001
# Household Income_2011_fast_food_interaction           1.231e-06   1.63e-06      0.757      0.455   -2.09e-06    4.55e-06
# Obese_2011_fast_food_interaction                         0.0052      0.004      1.210      0.236      -0.004       0.014
# African American_2011_fast_food_interaction              0.0293      0.028      1.027      0.313      -0.029       0.087
# Asian_2011_fast_food_interaction                        -0.0306      0.023     -1.356      0.185      -0.077       0.015
# Hispanic_2011_fast_food_interaction                     -0.0067      0.008     -0.812      0.423      -0.024       0.010
# Rural_2011_convenience_stores_interaction               -0.0006      0.001     -0.993      0.329      -0.002       0.001
# Household Income_2011_convenience_stores_interaction  2.578e-06   2.72e-06      0.949      0.350   -2.97e-06    8.13e-06
# Obese_2011_convenience_stores_interaction                0.0065      0.005      1.202      0.239      -0.005       0.018
# African American_2011_convenience_stores_interaction    -0.0694      0.054     -1.290      0.207      -0.179       0.040
# Asian_2011_convenience_stores_interaction                0.0356      0.040      0.902      0.374      -0.045       0.116
# Hispanic_2011_convenience_stores_interaction             0.0022      0.005      0.479      0.636      -0.007       0.012
# ==============================================================================
# Omnibus:                       11.329   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.695
# Skew:                           0.895   Prob(JB):                      0.00289
# Kurtosis:                       4.246   Cond. No.                     6.39e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.39e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# ...
# No. Observations:                  46   AIC:                             182.6
# Df Residuals:                      17   BIC:                             235.7
# Df Model:                          28
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -6.5927     12.249     -0.538      0.597     -32.436      19.251
# Percent_change_fast_food_restaurants_2011_2016          -0.2367      0.573     -0.413      0.685      -1.445       0.972
# Percent_change_convenience_stores_2011_2016             -1.0156      0.590     -1.720      0.104      -2.261       0.230
# Metro_nonmetro_counties_2010                             1.6499      0.849      1.944      0.069      -0.141       3.441
# African American_2011                                   -0.1069      0.049     -2.193      0.043      -0.210      -0.004
# Asian_2011                                               1.2826      1.292      0.993      0.335      -1.443       4.008
# Hispanic_2011                                           -0.1385      0.130     -1.068      0.300      -0.412       0.135
# Persistent_poverty_counties_2010                         2.9764      1.415      2.104      0.051      -0.008       5.961
# Population_loss_counties_2010                            1.7246      2.176      0.792      0.439      -2.867       6.316
# Recreation_fitness_facilities_2011                      -6.4907     16.777     -0.387      0.704     -41.887      28.905
# Grocery_stores_2011                                      0.0765      6.419      0.012      0.991     -13.466      13.619
# Low_access_to_stores_2010                              1.99e-05   2.44e-05      0.816      0.426   -3.15e-05    7.13e-05
# SNAP_benefits_per_capita_2012                            0.2775      0.087      3.176      0.006       0.093       0.462
# Household Income_2011                                    0.0002      0.000      1.359      0.192   -9.64e-05       0.000
# Obese_2011                                              -0.3080      0.295     -1.045      0.311      -0.930       0.314
# Rural_2011                                               0.0906      0.034      2.698      0.015       0.020       0.162
# change_rural                                             0.2638      0.101      2.601      0.019       0.050       0.478
# Rural_2011_fast_food_interaction                         0.0005      0.002      0.293      0.773      -0.003       0.004
# Household Income_2011_fast_food_interaction             2.2e-06   5.97e-06      0.369      0.717   -1.04e-05    1.48e-05
# Obese_2011_fast_food_interaction                         0.0029      0.018      0.165      0.871      -0.034       0.040
# African American_2011_fast_food_interaction              0.0015      0.003      0.501      0.623      -0.005       0.008
# Asian_2011_fast_food_interaction                         0.0224      0.080      0.280      0.783      -0.147       0.192
# Hispanic_2011_fast_food_interaction                     -0.0093      0.011     -0.852      0.406      -0.032       0.014
# Rural_2011_convenience_stores_interaction                0.0030      0.002      1.461      0.162      -0.001       0.007
# Household Income_2011_convenience_stores_interaction  1.357e-05   6.79e-06      1.998      0.062   -7.61e-07    2.79e-05
# Obese_2011_convenience_stores_interaction                0.0044      0.023      0.191      0.851      -0.045       0.053
# African American_2011_convenience_stores_interaction     0.0047      0.004      1.039      0.313      -0.005       0.014
# Asian_2011_convenience_stores_interaction                0.0948      0.105      0.904      0.379      -0.127       0.316
# Hispanic_2011_convenience_stores_interaction            -0.0057      0.009     -0.624      0.541      -0.025       0.013
# ==============================================================================
# Omnibus:                        1.217   Durbin-Watson:                   1.743
# Prob(Omnibus):                  0.544   Jarque-Bera (JB):                0.830
# Skew:                           0.329   Prob(JB):                        0.660
# Kurtosis:                       3.012   Cond. No.                     5.15e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.15e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for Connecticut:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):                nan
# Time:                        23:56:09   Log-Likelihood:                 240.66
# No. Observations:                   8   AIC:                            -465.3
# Df Residuals:                       0   BIC:                            -464.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 -1.16e-05        inf         -0        nan         nan         nan
# Percent_change_fast_food_restaurants_2011_2016          -0.0001        inf         -0        nan         nan         nan
# Percent_change_convenience_stores_2011_2016              0.0001        inf          0        nan         nan         nan
# Metro_nonmetro_counties_2010                         -1.398e-05        inf         -0        nan         nan         nan
# African American_2011                                    0.0001        inf          0        nan         nan         nan
# Asian_2011                                           -1.206e-05        inf         -0        nan         nan         nan
# Hispanic_2011                                           -0.0004        inf         -0        nan         nan         nan
# Persistent_poverty_counties_2010                              0        nan        nan        nan         nan         nan
# Population_loss_counties_2010                                 0        nan        nan        nan         nan         nan
# Recreation_fitness_facilities_2011                    2.847e-06        inf          0        nan         nan         nan
# Grocery_stores_2011                                   9.974e-06        inf          0        nan         nan         nan
# Low_access_to_stores_2010                             1.549e-05        inf          0        nan         nan         nan
# SNAP_benefits_per_capita_2012                           -0.0005        inf         -0        nan         nan         nan
# Household Income_2011                                 5.987e-05        inf          0        nan         nan         nan
# Obese_2011                                              -0.0007        inf         -0        nan         nan         nan
# Rural_2011                                              -0.0017        inf         -0        nan         nan         nan
# change_rural                                            -0.0005        inf         -0        nan         nan         nan
# Rural_2011_fast_food_interaction                        -0.0014        inf         -0        nan         nan         nan
# Household Income_2011_fast_food_interaction            3.86e-06        inf          0        nan         nan         nan
# Obese_2011_fast_food_interaction                        -0.0082        inf         -0        nan         nan         nan
# African American_2011_fast_food_interaction             -0.0046        inf         -0        nan         nan         nan
# Asian_2011_fast_food_interaction                        -0.0018        inf         -0        nan         nan         nan
# Hispanic_2011_fast_food_interaction                     -0.0126        inf         -0        nan         nan         nan
# Rural_2011_convenience_stores_interaction                0.0049        inf          0        nan         nan         nan
# Household Income_2011_convenience_stores_interaction -4.933e-06        inf         -0        nan         nan         nan
# Obese_2011_convenience_stores_interaction                0.0047        inf          0        nan         nan         nan
# African American_2011_convenience_stores_interaction    -0.0021        inf         -0        nan         nan         nan
# Asian_2011_convenience_stores_interaction               -0.0041        inf         -0        nan         nan         nan
# Hispanic_2011_convenience_stores_interaction            -0.0027        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        4.753   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                0.940
# Skew:                           0.729   Prob(JB):                        0.625
# Kurtosis:                       3.833   Cond. No.                     7.30e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 7.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for Tennessee:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           change_obese   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     1.980
# Date:                Sat, 03 Aug 2024   Prob (F-statistic):             0.0125
# Time:                        23:56:09   Log-Likelihood:                -191.01
# No. Observations:                  95   AIC:                             438.0
# Df Residuals:                      67   BIC:                             509.5
# Df Model:                          27
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   12.8322      7.655      1.676      0.098      -2.447      28.111
# Percent_change_fast_food_restaurants_2011_2016           0.1829      0.274      0.667      0.507      -0.364       0.730
# Percent_change_convenience_stores_2011_2016              0.4059      0.276      1.472      0.146      -0.145       0.956
# Metro_nonmetro_counties_2010                             0.2439      0.666      0.366      0.715      -1.086       1.574
# African American_2011                                    0.0654      0.043      1.530      0.131      -0.020       0.151
# Asian_2011                                              -0.8203      0.763     -1.075      0.286      -2.344       0.703
# Hispanic_2011                                            0.0747      0.135      0.555      0.581      -0.194       0.344
# Persistent_poverty_counties_2010                        -1.0811      1.107     -0.977      0.332      -3.291       1.129
# Population_loss_counties_2010                         8.139e-12   5.07e-12      1.604      0.113   -1.99e-12    1.83e-11
# Recreation_fitness_facilities_2011                      13.5063      8.258      1.636      0.107      -2.977      29.989
# Grocery_stores_2011                                     -0.7097      3.566     -0.199      0.843      -7.828       6.408
# Low_access_to_stores_2010                            -2.238e-05   1.06e-05     -2.116      0.038   -4.35e-05   -1.27e-06
# SNAP_benefits_per_capita_2012                            0.0982      0.067      1.458      0.149      -0.036       0.233
# Household Income_2011                                 5.284e-05   5.63e-05      0.939      0.351   -5.95e-05       0.000
# Obese_2011                                              -0.5247      0.205     -2.560      0.013      -0.934      -0.116
# Rural_2011                                              -0.0007      0.019     -0.035      0.972      -0.038       0.037
# change_rural                                             0.1030      0.045      2.267      0.027       0.012       0.194
# Rural_2011_fast_food_interaction                         0.0013      0.001      1.634      0.107      -0.000       0.003
# Household Income_2011_fast_food_interaction          -3.807e-06   2.53e-06     -1.506      0.137   -8.85e-06    1.24e-06
# Obese_2011_fast_food_interaction                        -0.0072      0.008     -0.943      0.349      -0.023       0.008
# African American_2011_fast_food_interaction              0.0003      0.002      0.161      0.873      -0.003       0.004
# Asian_2011_fast_food_interaction                         0.0756      0.035      2.142      0.036       0.005       0.146
# Hispanic_2011_fast_food_interaction                      0.0216      0.008      2.750      0.008       0.006       0.037
# Rural_2011_convenience_stores_interaction               -0.0007      0.001     -1.121      0.266      -0.002       0.001
# Household Income_2011_convenience_stores_interaction  2.546e-06   1.72e-06      1.482      0.143   -8.83e-07    5.98e-06
# Obese_2011_convenience_stores_interaction               -0.0136      0.008     -1.718      0.090      -0.029       0.002
# African American_2011_convenience_stores_interaction     0.0012      0.002      0.662      0.510      -0.002       0.005
# Asian_2011_convenience_stores_interaction               -0.0367      0.046     -0.797      0.428      -0.129       0.055
# Hispanic_2011_convenience_stores_interaction            -0.0047      0.007     -0.650      0.518      -0.019       0.010
# ==============================================================================
# Omnibus:                        1.129   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.569   Jarque-Bera (JB):                0.655
# Skew:                           0.160   Prob(JB):                        0.721
# Kurtosis:                       3.250   Cond. No.                     1.10e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.73e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.api as sm
import pandas as pd

# Initialize a dictionary to store the coefficients for each state
statewise_coefficients = {}

# Get the list of unique states
states = cleaned_data['State_2011'].unique()

# Loop over each state
for state in states:
    # Filter the data for the current state
    state_data = cleaned_data[cleaned_data['State_2011'] == state]
    
    # Drop rows with NaNs or Infs
    X_state = sm.add_constant(state_data[predictors_with_interactions].replace([np.inf, -np.inf], np.nan).dropna())
    Y_state = state_data.loc[X_state.index, 'change_obese']  # Align Y with X
    
    # Ensure there are enough data points to run the model
    if len(Y_state) < 2:
        print(f"Not enough data points for {state}. Skipping this state.")
        continue
    
    # Fit the model
    model_state = sm.OLS(Y_state, X_state).fit()
    
    # Extract the coefficients for the variables of interest
    coeffs = model_state.params[['Percent_change_fast_food_restaurants_2011_2016', 
                                 'Percent_change_convenience_stores_2011_2016']]
    pvals = model_state.pvalues[['Percent_change_fast_food_restaurants_2011_2016', 
                                 'Percent_change_convenience_stores_2011_2016']]
    
    # Store the coefficients and p-values in the dictionary
    statewise_coefficients[state] = {'coefficients': coeffs, 'p-values': pvals}

# Print the results for each state
print("Statewise Coefficients and P-values:")
for state, results in statewise_coefficients.items():
    print(f"\nResults for {state}:")
    print(f"Percent_change_fast_food_restaurants_2011_2016: Coefficient = {results['coefficients']['Percent_change_fast_food_restaurants_2011_2016']}, P-value = {results['p-values']['Percent_change_fast_food_restaurants_2011_2016']}")
    print(f"Percent_change_convenience_stores_2011_2016: Coefficient = {results['coefficients']['Percent_change_convenience_stores_2011_2016']}, P-value = {results['p-values']['Percent_change_convenience_stores_2011_2016']}")
# Out:
# Statewise Coefficients and P-values:
#
# Results for Wisconsin:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.14602894241094316, P-value = 0.6978993224715544
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.018146717908706866, P-value = 0.9765933643605793
#
# Results for Washington:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.596413676228267, P-value = 0.5065615197056073
# Percent_change_convenience_stores_2011_2016: Coefficient = -1.0928997963493234, P-value = 0.11832251310533183
#
# Results for New Hampshire:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.02809524613850493, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.025993239659559523, P-value = nan
#
# Results for Alaska:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.8604399847527264, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.5635977349682794, P-value = nan
#
# Results for Hawaii:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -3.99525791982694e-11, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -2.1555772241897548e-11, P-value = nan
#
# Results for South Dakota:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.16701828922867454, P-value = 0.3267980269834959
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.22091484001752065, P-value = 0.40270579245459237
#
# Results for North Carolina:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.031055504858679195, P-value = 0.9098736059015782
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.10401791420403417, P-value = 0.7014290438295385
#
# Results for Kansas:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.8113328666932441, P-value = 0.009365824914119249
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.08318054558218158, P-value = 0.7938500585209878
#
# Results for Iowa:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.18269445776603943, P-value = 0.5327433231926233
# Percent_change_convenience_stores_2011_2016: Coefficient = -1.000641960525732, P-value = 0.03862216296537898
#
# Results for Arizona:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.018779166568183965, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.010718912544485157, P-value = nan
#
# Results for Massachusetts:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.001659880907371342, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.0073279841990534856, P-value = nan
#
# Results for Florida:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.2596797272651947, P-value = 0.46188099822829864
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.16156961597034014, P-value = 0.760497082243579
#
# Results for Indiana:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.03473889212553527, P-value = 0.962377692119751
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.3955234762819658, P-value = 0.5792773123069087
#
# Results for Oklahoma:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.7230153181130585, P-value = 0.22127071976713672
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.10783071769460201, P-value = 0.8109608032604083
#
# Results for Texas:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.09260370448873778, P-value = 0.46729666300992423
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.2737532474731309, P-value = 0.0912790334884442
#
# Results for Ohio:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.5407825920382661, P-value = 0.4791231840330622
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.3879463540168883, P-value = 0.5827326690177063
#
# Results for Utah:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 2.484553317695841, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -3.12393572651723, P-value = nan
#
# Results for North Dakota:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.06910834043527775, P-value = 0.7314147447470046
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.3193130395856931, P-value = 0.31085534803736087
#
# Results for Wyoming:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.15503341798526363, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.16965493386072628, P-value = nan
#
# Results for Kentucky:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.11698744675870514, P-value = 0.6122778797449857
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.4946146553701836, P-value = 0.007901943038775963
#
# Results for Arkansas:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.04904311071302471, P-value = 0.7564145392436247
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.1888029349003865, P-value = 0.22635884196614972
#
# Results for West Virginia:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.17133043216417265, P-value = 0.6754654355513126
# Percent_change_convenience_stores_2011_2016: Coefficient = 1.0939316065884186, P-value = 0.28511806419246566
#
# Results for Virginia:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.13608068099790407, P-value = 0.7075230607884109
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.006722412197727498, P-value = 0.9870944486933824
#
# Results for Nebraska:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.03663952432675219, P-value = 0.8923241661238458
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.03931462537475575, P-value = 0.867671777886615
#
# Results for New Jersey:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.27805699863921274, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.1842556027925305, P-value = nan
#
# Results for Colorado:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.20771624470580577, P-value = 0.347158876529176
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.15808474321419821, P-value = 0.4312706902160103
#
# Results for New York:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.24115995953323066, P-value = 0.7290606900456679
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.05328307590051401, P-value = 0.9025936203273012
#
# Results for Michigan:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.47589858048329536, P-value = 0.27428135989820474
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.22614499714554248, P-value = 0.6938465133416903
#
# Results for Louisiana:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.3371117151449145, P-value = 0.5075027685790678
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.0736896643143217, P-value = 0.8594886071883121
#
# Results for Maine:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.18392844189547386, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.052090505034459826, P-value = nan
#
# Results for Mississippi:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.049345016173938265, P-value = 0.87805103180705
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.031269332359598986, P-value = 0.9105572567992948
#
# Results for Georgia:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.07296319860555564, P-value = 0.754317218065107
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.16557975123754273, P-value = 0.5656362323530482
#
# Results for Alabama:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 1.0599740625048257, P-value = 0.006088788559175469
# Percent_change_convenience_stores_2011_2016: Coefficient = 1.3191490684442082, P-value = 0.04008004497453368
#
# Results for Illinois:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.11785507379542594, P-value = 0.8453815255873214
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.28801503259071565, P-value = 0.5420946935639048
#
# Results for Pennsylvania:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.674497848305602, P-value = 0.0887669033788584
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.18564318869296154, P-value = 0.7134918722063056
#
# Results for Maryland:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 1.805679881960258, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.41363134682146296, P-value = nan
#
# Results for Montana:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.09167708657511076, P-value = 0.3701441768104663
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.07545032378026668, P-value = 0.6062354459216712
#
# Results for New Mexico:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.28870572718656023, P-value = 0.6764152174518585
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.9832616747291214, P-value = 0.4310758175414266
#
# Results for Oregon:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.2333992357228871, P-value = 0.6626245117462275
# Percent_change_convenience_stores_2011_2016: Coefficient = -2.136245133287767, P-value = 0.032167019508899886
#
# Results for Delaware:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -1.510967640505858e-10, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -6.335167667970978e-11, P-value = nan
#
# Results for Idaho:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.11575815792834807, P-value = 0.7914865965443029
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.43165271283200035, P-value = 0.6215162545833157
#
# Results for Missouri:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.27658459405212493, P-value = 0.3349137270813264
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.012271577950305063, P-value = 0.9780792080635322
#
# Results for California:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.8092304682558445, P-value = 0.0039037209946656912
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.5361684282530093, P-value = 0.23356006931803192
#
# Results for Minnesota:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 1.1638726453711654, P-value = 0.01846524309078822
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.6740312239964401, P-value = 0.19751832781251033
#
# Results for Rhode Island:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -7.687783486224933e-06, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 7.486693436745682e-05, P-value = nan
#
# Results for Nevada:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.03637097958418278, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.05531169715252331, P-value = nan
#
# Results for Vermont:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.03534473207986264, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = -0.05816496740749531, P-value = nan
#
# Results for South Carolina:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.23667746609791324, P-value = 0.6846038552030076
# Percent_change_convenience_stores_2011_2016: Coefficient = -1.0156438748016707, P-value = 0.1035216589376356
#
# Results for Connecticut:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = -0.00013965690249559756, P-value = nan
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.0001159043729614476, P-value = nan
#
# Results for Tennessee:
# Percent_change_fast_food_restaurants_2011_2016: Coefficient = 0.18289918520622983, P-value = 0.5067587047063171
# Percent_change_convenience_stores_2011_2016: Coefficient = 0.4059317098637622, P-value = 0.14570968141247126

# %%
import pandas as pd

# Initialize a dictionary to store the correlations for each state
statewise_correlations = {}

# Get the list of unique states
states = cleaned_data['State_2011'].unique()

# Loop over each state
for state in states:
    # Filter the data for the current state
    state_data = cleaned_data[cleaned_data['State_2011'] == state]
    
    # Drop rows with NaNs in relevant columns
    relevant_columns = ['change_obese', 
                        'Percent_change_fast_food_restaurants_2011_2016', 
                        'Percent_change_convenience_stores_2011_2016']
    state_data = state_data.dropna(subset=relevant_columns)
    
    # Ensure there are enough data points to calculate correlation
    if len(state_data) < 2:
        print(f"Not enough data points for {state}. Skipping this state.")
        continue
    
    # Calculate correlations
    corr_fast_food = state_data['change_obese'].corr(state_data['Percent_change_fast_food_restaurants_2011_2016'])
    corr_convenience_stores = state_data['change_obese'].corr(state_data['Percent_change_convenience_stores_2011_2016'])
    
    # Store the correlations in the dictionary
    statewise_correlations[state] = {'fast_food_correlation': corr_fast_food, 
                                     'convenience_stores_correlation': corr_convenience_stores}

# Print the results for each state
print("Statewise Correlations:")
for state, correlations in statewise_correlations.items():
    print(f"\nResults for {state}:")
    print(f"Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: {correlations['fast_food_correlation']}")
    print(f"Correlation between change_obese and Percent_change_convenience_stores_2011_2016: {correlations['convenience_stores_correlation']}")
# Out:
# Statewise Correlations:
#
# Results for Wisconsin:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.15206950204965003
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.06059281940422395
#
# Results for Washington:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.16662976271498886
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.3713534343517192
#
# Results for New Hampshire:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.13757063394190752
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.5132927807855462
#
# Results for Alaska:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.37521445811936366
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.025999025979616786
#
# Results for Hawaii:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.40733931917194804
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.5919562054235112
#
# Results for South Dakota:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.20068959911131803
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.25278989530907015
#
# Results for North Carolina:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.08181907276819024
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.18478106286336843
#
# Results for Kansas:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.18648418034230005
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.11528709280522126
#
# Results for Iowa:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.1459657689699357
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.1346200910126355
#
# Results for Arizona:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.08766057794382313
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.2033525864610583
#
# Results for Massachusetts:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.2824828249350488
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.00542349696857656
#
# Results for Florida:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.07488421512499607
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.07376384652109146
#
# Results for Indiana:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.11619002611084282
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.042333796147165
#
# Results for Oklahoma:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.05718057561530858
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.21921293235961517
#
# Results for Texas:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.023599052491349477
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.029763550190184257
#
# Results for Ohio:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.06939139352069958
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.06572074808121901
#
# Results for Utah:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.1484073095332696
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.20416054528240815
#
# Results for North Dakota:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.06410052207434601
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.003333386196926626
#
# Results for Wyoming:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.47963731793361497
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.13740524663719095
#
# Results for Kentucky:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.15374703133960074
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.03879042666659335
#
# Results for Arkansas:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.00993477055545752
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.11351632154868431
#
# Results for West Virginia:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.06974156431559252
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.23838742638842103
#
# Results for Virginia:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.018682861554607962
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.05502720777202384
#
# Results for Nebraska:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.053629324210768756
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.22955270011990214
#
# Results for New Jersey:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.13804456660033632
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.17016548696101502
#
# Results for Colorado:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.2558827847099004
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.1251520718454154
#
# Results for New York:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.1105202817610172
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.1855738868691117
#
# Results for Michigan:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.16636239415872894
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.2614516685097037
#
# Results for Louisiana:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.062577002035774
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.11634554227538042
#
# Results for Maine:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.2859036166537996
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.2284591340768575
#
# Results for Mississippi:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.0853821880511503
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.12890718634025394
#
# Results for Georgia:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.0350179922419262
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.030924413900468014
#
# Results for Alabama:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.09533482495957186
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.17233617403704682
#
# Results for Illinois:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.04993685611531201
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.0018220607582819489
#
# Results for Pennsylvania:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.0009135269405253946
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.011621538276614876
#
# Results for Maryland:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.09383430800558677
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.1047546017910837
#
# Results for Montana:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.17656661815049843
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.26116548041955207
#
# Results for New Mexico:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.00889146450477745
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.10934184843102655
#
# Results for Oregon:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.10938767913209396
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.14303371990201952
#
# Results for Delaware:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.9851035151311174
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.39631660807051794
#
# Results for Idaho:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.23424940271748762
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.12124449176124344
#
# Results for Missouri:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.021643513615314226
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.1676908271216104
#
# Results for California:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.0032075247365109917
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.1729840476714216
#
# Results for Minnesota:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.05508476312245946
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.043869898576850426
#
# Results for Rhode Island:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: -0.42347442223898285
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.35408101644644135
#
# Results for Nevada:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.03569615701914574
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.3968797219511153
#
# Results for Vermont:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.2936432832398818
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.49741318677162155
#
# Results for South Carolina:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.023617030496788115
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: 0.3651902150222493
#
# Results for Connecticut:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.1760428033531508
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.15643053547456295
#
# Results for Tennessee:
# Correlation between change_obese and Percent_change_fast_food_restaurants_2011_2016: 0.1851578731742824
# Correlation between change_obese and Percent_change_convenience_stores_2011_2016: -0.11706254728570138

# %%
import statsmodels.api as sm
import pandas as pd

# Initialize a list to store the prediction results
prediction_results = []

# Get the list of unique states
states = cleaned_data['State_2011'].unique()

# Define the increase in fast food restaurants
increase_in_fast_food = 10

# Loop over each state
for state in states:
    # Filter the data for the current state
    state_data = cleaned_data[cleaned_data['State_2011'] == state]
    
    # Drop rows with NaNs or Infs
    X_state = sm.add_constant(state_data[predictor_columns].replace([np.inf, -np.inf], np.nan).dropna())
    Y_state = state_data.loc[X_state.index, 'change_obese']  # Align Y with X
    
    # Ensure there are enough data points to run the model
    if len(Y_state) < 2:
        print(f"Not enough data points for {state}. Skipping this state.")
        continue
    
    # Fit the model
    model_state = sm.OLS(Y_state, X_state).fit()
    
    # Create a copy of X_state to modify for the prediction
    X_state_modified = X_state.copy()
    
    # Increase the Percent_change_fast_food_restaurants_2011_2016 by 10
    X_state_modified['Percent_change_fast_food_restaurants_2011_2016'] += increase_in_fast_food
    
    # Predict the change in obesity
    predicted_change = model_state.predict(X_state_modified)
    
    # Store the results
    state_results = pd.DataFrame({
        'FIPS': state_data.loc[X_state.index, 'FIPS'],
        'State': state,
        'County': state_data.loc[X_state.index, 'County_2011'],
        'Predicted_change_obese': predicted_change
    })
    
    prediction_results.append(state_results)

# Combine all the results into a single DataFrame
final_results = pd.concat(prediction_results, ignore_index=True)

# Save the results to a CSV file
final_results.to_csv('predicted_obesity_changes.csv', index=False)

print("Predicted obesity changes have been saved to 'predicted_obesity_changes.csv'.")
# Out:
# Predicted obesity changes have been saved to 'predicted_obesity_changes.csv'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the predicted values from the CSV file (assuming it's named 'predicted_obesity_changes.csv')
predicted_data = pd.read_csv('predicted_obesity_changes.csv')

# Merge the predicted data with the original cleaned data to get the features
merged_data_with_predictions = pd.merge(cleaned_data, predicted_data, on=['FIPS'])

# Select the relevant features and the predicted change in obesity
features_to_explore = [
    'Percent_change_fast_food_restaurants_2011_2016',
    'Percent_change_convenience_stores_2011_2016',
    'Rural_2011', 
    'Household Income_2011', 
    'Obese_2011', 
    'African American_2011', 
    'Asian_2011', 
    'Hispanic_2011'
]

# Create a DataFrame with the features and the predicted change in obesity
# analysis_data = merged_data_with_predictions[features_to_explore + ['Predicted_change_obese']]

# # Pairplot to visualize relationships between features and predicted change in obesity
# sns.pairplot(analysis_data, y_vars=['Predicted_change_obese'], x_vars=features_to_explore, kind='reg')
# plt.suptitle("Relationships Between Features and Predicted Change in Obesity", y=1.02)
# plt.show()

# Heatmap to visualize correlations between features and predicted change in obesity
correlation_matrix = analysis_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Between Features and Predicted Change in Obesity")
plt.show()

# # Scatter plot to visualize predicted change in obesity against key features
# for feature in features_to_explore:
#     plt.figure(figsize=(8, 6))
#     sns.scatterplot(x=analysis_data[feature], y=analysis_data['Predicted_change_obese'])
#     plt.title(f"Predicted Change in Obesity vs {feature}")
#     plt.xlabel(feature)
#     plt.ylabel('Predicted Change in Obesity')
#     plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# Load the cleaned data
# Assume `cleaned_data` is already available from the previous steps

# Initialize a list to store the prediction results
prediction_results = []

# Get the list of unique states
states = cleaned_data['State_2011'].unique()

# Loop over each state
for state in states:
    # Filter the data for the current state
    state_data = cleaned_data[cleaned_data['State_2011'] == state]
    
    # Drop rows with NaNs in predictor or response columns
    state_data = state_data.dropna(subset=[
        'change_obese', 
        'change_binge_drinking', 
        'change_physical_inactivity', 
        'change_mentally_unhealthy_days',
        'change_fair_poor_health', 
        'Percent_change_fast_food_restaurants_2011_2016', 
        'Percent_change_convenience_stores_2011_2016'
    ])
    
    # Check if there's enough data to build a model
    if state_data.shape[0] < 2:
        print(f"Not enough data for state: {state}")
        continue
    
    # Define predictors and responses
    predictors = [
        'Percent_change_fast_food_restaurants_2011_2016',
        'Percent_change_convenience_stores_2011_2016',
    ]
    
    responses = [
        'change_obese',
        'change_binge_drinking', 
        'change_physical_inactivity', 
        'change_mentally_unhealthy_days', 
        'change_fair_poor_health'
    ]
    
    # Add a constant term for the intercept in the regression
    X = sm.add_constant(state_data[predictors])
    
    # Dictionary to hold the predictions for this state
    state_predictions = {'FIPS': state_data['FIPS'], 'State': state, 'County': state_data['County_2011']}
    
    # Fit a model for each response variable and make predictions
    for response in responses:
        Y = state_data[response]
        model = sm.OLS(Y, X).fit()
        
        # Predicting with the same data (you can also change predictors for new scenarios)
        state_predictions[f'Predicted_{response}'] = model.predict(X)
    
    # Convert the dictionary to a DataFrame and append to the results list
    state_predictions_df = pd.DataFrame(state_predictions)
    prediction_results.append(state_predictions_df)

# Combine all the state-specific predictions into a single DataFrame
final_predictions = pd.concat(prediction_results, ignore_index=True)

# Save the predictions to a CSV file
final_predictions.to_csv('new_state_specific_predictions.csv', index=False)

print("Predictions for each state have been saved to 'state_specific_predictions.csv'.")
# Out:
# Predictions for each state have been saved to 'state_specific_predictions.csv'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the predictions
predictions = pd.read_csv('new_state_specific_predictions.csv')

# Merge predictions with the original cleaned data to get the features
merged_data_with_predictions = pd.merge(cleaned_data, predictions, on=['FIPS'])

# Define a threshold for "high" predicted obesity rate
# For example, let's consider the top 20% of predicted obesity rates as "high"
threshold = merged_data_with_predictions['Predicted_change_obese'].quantile(0.80)
high_obesity_data = merged_data_with_predictions[merged_data_with_predictions['Predicted_change_obese'] > threshold]

# Calculate correlations between high predicted obesity rates and features
features_to_correlate = [
    'Percent_change_fast_food_restaurants_2011_2016',
    'Percent_change_convenience_stores_2011_2016',
    'Rural_2011', 
    'Household Income_2011', 
    'Obese_2011', 
    'African American_2011', 
    'Asian_2011', 
    'Hispanic_2011'
]

# Add interaction terms if needed
interaction_terms = [
    'Rural_2011_fast_food_interaction',
    'Rural_2011_convenience_stores_interaction',
    'Household Income_2011_fast_food_interaction',
    'Household Income_2011_convenience_stores_interaction',
    'Obese_2011_fast_food_interaction',
    'Obese_2011_convenience_stores_interaction'
]

# Combine the features and interaction terms
all_features = features_to_correlate + interaction_terms

# Correlation matrix for high predicted obesity rates with features
correlation_matrix = high_obesity_data[['Predicted_change_obese'] + all_features].corr()

# Visualize the correlations using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Between Features and High Predicted Change in Obesity")
plt.tight_layout()
plt.show()

# Optional: Scatter plot for a detailed view of the most correlated features
for feature in all_features:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=high_obesity_data[feature], y=high_obesity_data['Predicted_change_obese'])
    plt.title(f"Predicted Change in Obesity vs {feature}")
    plt.xlabel(feature)
    plt.ylabel('Predicted Change in Obesity')
    plt.tight_layout()
    plt.show()

# %%
cleaned_data.columns
# Out:
# Index(['FIPS', 'State_2011', 'County_2011', 'Rural_2011',
#        'Household Income_2011', 'African American_2011', 'Asian_2011',
#        'Hispanic_2011', 'Obese_2011', 'PCP Ratio_2011', 'change_rural',
#        'change_obese', 'change_binge_drinking', 'change_physical_inactivity',
#        'change_mentally_unhealthy_days', 'change_fair_poor_health',
#        'Percent_change_fast_food_restaurants_2011_2016',
#        'Percent_change_convenience_stores_2011_2016',
#        'Metro_nonmetro_counties_2010', 'Persistent_poverty_counties_2010',
#        'Population_loss_counties_2010', 'Recreation_fitness_facilities_2011',
#        'Grocery_stores_2011', 'Low_access_to_stores_2010',
#        'SNAP_benefits_per_capita_2012', 'WIC_redemptions_per_capita_2011',
#        'Rural_2011_fast_food_interaction',
#        'Rural_2011_convenience_stores_interaction',
#        'Household Income_2011_fast_food_interaction',
#        'Household Income_2011_convenience_stores_interaction',
#        'Obese_2011_fast_food_interaction',
#        'Obese_2011_convenience_stores_interaction',
#        'African American_2011_fast_food_interaction',
#        'African American_2011_convenience_stores_interaction',
#        'Asian_2011_fast_food_interaction',
#        'Asian_2011_convenience_stores_interaction',
#        'Hispanic_2011_fast_food_interaction',
#        'Hispanic_2011_convenience_stores_interaction', 'State', 'County',
#        'Predicted_change_obese', 'Predicted_change_binge_drinking',
#        'Predicted_change_physical_inactivity',
#        'Predicted_change_mentally_unhealthy_days',
#        'Predicted_change_fair_poor_health', 'Rural_2011_bin'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the predictions
predictions = pd.read_csv('new_state_specific_predictions.csv')
print(predictions.columns)

# Merge predictions with the original cleaned data to get the features
merged_data_with_predictions = pd.merge(cleaned_data, predictions, on=['FIPS'])

print(merged_data_with_predictions.columns)

# Define the features to correlate with the predicted change in obesity
features_to_correlate = [
    'Rural_2011', 
    'change_rural',
    'PCP Ratio_2011',
    'Metro_nonmetro_counties_2010', 'Persistent_poverty_counties_2010',
       'Population_loss_counties_2010', 'Recreation_fitness_facilities_2011',
    'Grocery_stores_2011', 'Low_access_to_stores_2010',
    'SNAP_benefits_per_capita_2012',
    'Household Income_2011', 
    'Obese_2011', 
    'African American_2011', 
    'Asian_2011', 
    'Hispanic_2011'
]

# Add the predicted change in obesity to the features list
features_with_predicted_obesity = features_to_correlate + ['Predicted_change_obese_x']

# Calculate the correlation matrix
correlation_matrix = merged_data_with_predictions[features_with_predicted_obesity].corr()

# Extract correlations of the selected features with predicted change in obesity
correlations = correlation_matrix['Predicted_change_obese_x'].drop('Predicted_change_obese_x')

# Plot the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlations.index, y=correlations.values, palette='coolwarm')
plt.title('Correlation Between Selected Features and Predicted Change in Obesity')
plt.xlabel('Features')
plt.ylabel('Correlation with Predicted Change in Obesity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['FIPS', 'State', 'County', 'Predicted_change_obese',
#        'Predicted_change_binge_drinking',
#        'Predicted_change_physical_inactivity',
#        'Predicted_change_mentally_unhealthy_days',
#        'Predicted_change_fair_poor_health'],
#       dtype='object')
# Index(['FIPS', 'State_2011', 'County_2011', 'Rural_2011',
#        'Household Income_2011', 'African American_2011', 'Asian_2011',
#        'Hispanic_2011', 'Obese_2011', 'PCP Ratio_2011', 'change_rural',
#        'change_obese', 'change_binge_drinking', 'change_physical_inactivity',
#        'change_mentally_unhealthy_days', 'change_fair_poor_health',
#        'Percent_change_fast_food_restaurants_2011_2016',
#        'Percent_change_convenience_stores_2011_2016',
#        'Metro_nonmetro_counties_2010', 'Persistent_poverty_counties_2010',
#        'Population_loss_counties_2010', 'Recreation_fitness_facilities_2011',
#        'Grocery_stores_2011', 'Low_access_to_stores_2010',
#        'SNAP_benefits_per_capita_2012', 'WIC_redemptions_per_capita_2011',
#        'Rural_2011_fast_food_interaction',
#        'Rural_2011_convenience_stores_interaction',
#        'Household Income_2011_fast_food_interaction',
#        'Household Income_2011_convenience_stores_interaction',
#        'Obese_2011_fast_food_interaction',
#        'Obese_2011_convenience_stores_interaction',
#        'African American_2011_fast_food_interaction',
#        'African American_2011_convenience_stores_interaction',
#        'Asian_2011_fast_food_interaction',
#        'Asian_2011_convenience_stores_interaction',
#        'Hispanic_2011_fast_food_interaction',
#        'Hispanic_2011_convenience_stores_interaction', 'State_x', 'County_x',
#        'Predicted_change_obese_x', 'Predicted_change_binge_drinking_x',
#        'Predicted_change_physical_inactivity_x',
#        'Predicted_change_mentally_unhealthy_days_x',
#        'Predicted_change_fair_poor_health_x', 'Rural_2011_bin', 'State_y',
#        'County_y', 'Predicted_change_obese_y',
#        'Predicted_change_binge_drinking_y',
#        'Predicted_change_physical_inactivity_y',
#        'Predicted_change_mentally_unhealthy_days_y',
#        'Predicted_change_fair_poor_health_y'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 34
#      31 features_with_predicted_obesity = features_to_correlate + ['Predicted_change_obese_x']
#      33 # Calculate the correlation matrix
# ---> 34 correlation_matrix = merged_data_with_predictions[features_with_predicted_obesity].corr()
#      36 # Extract correlations of the selected features with predicted change in obesity
#      37 correlations = correlation_matrix['Predicted_change_obese_x'].drop('Predicted_change_obese_x')
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '4057:1'

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Prepare your data
X = merged_data_with_predictions[features_to_correlate]
y = merged_data_with_predictions['Predicted_change_obese']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Get feature importances
feature_importances = pd.Series(rf_model.feature_importances_, index=features_to_correlate)
feature_importances.sort_values().plot(kind='barh', figsize=(10, 6), title='Feature Importance in Predicting Change in Obesity')
plt.show()

# %%
cleaned_data = merged_data_with_predictions

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Define environmental features
environmental_features = [
    'Rural_2011', 
    'Household Income_2011', 
    'Obese_2011', 
    'African American_2011', 
    'Asian_2011', 
    'Hispanic_2011'
]

# Define key predictors (focus of the analysis)
key_predictors = [
    'Percent_change_fast_food_restaurants_2011_2016',
    'Percent_change_convenience_stores_2011_2016'
]

# Function to train and return feature importances
def train_and_get_importance(X, y, predictors):
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model.fit(X[predictors], y)
    return pd.Series(rf_model.feature_importances_, index=predictors)

# Stratify data by each environmental feature
for feature in environmental_features:
    # Create bins based on quantiles for stratification
    bins = pd.qcut(cleaned_data[feature], q=3, labels=False)
    cleaned_data[f'{feature}_bin'] = bins
    
    # Collect feature importances for each bin
    importances = []
    for bin_value in cleaned_data[f'{feature}_bin'].unique():
        # Filter data for the current bin
        bin_data = cleaned_data[cleaned_data[f'{feature}_bin'] == bin_value]
        
        # Define predictors and target
        X = bin_data[key_predictors]
        y = bin_data['Predicted_change_obese']
        
        # Calculate feature importances
        importance = train_and_get_importance(X, y, key_predictors)
        importances.append(importance)
    
    # Visualize the importance differences for the feature
    importance_df = pd.DataFrame(importances, index=[f'Low {feature}', f'High {feature}'])
    importance_df.plot(kind='barh', title=f'Feature Importance Stratified by {feature}', figsize=(10, 6))
    plt.xlabel('Importance Score')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 46
#      43     y = bin_data['Predicted_change_obese']
#      45     # Calculate feature importances
# ---> 46     importance = train_and_get_importance(X, y, key_predictors)
#      47     importances.append(importance)
#      49 # Visualize the importance differences for the feature
#
# Cell In[32], line 26, in train_and_get_importance(X, y, predictors)
#      24 def train_and_get_importance(X, y, predictors):
#      25     rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
# ---> 26     rf_model.fit(X[predictors], y)
#      27     return pd.Series(rf_model.feature_importances_, index=predictors)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/sklearn/utils/validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File ~/opt/anaconda3/envs/citadel-datathon24/lib/python3.11/site-packages/sklearn/utils/validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1085     n_samples = _num_samples(array)
#    1086     if n_samples < ensure_min_samples:
# -> 1087         raise ValueError(
#    1088             "Found array with %d sample(s) (shape=%s) while a"
#    1089             " minimum of %d is required%s."
#    1090             % (n_samples, array.shape, ensure_min_samples, context)
#    1091         )
#    1093 if ensure_min_features > 0 and array.ndim == 2:
#    1094     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by RandomForestRegressor.
